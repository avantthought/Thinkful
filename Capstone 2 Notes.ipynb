# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline
df = pd.read_csv('vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df1 = df.dropna()
df1
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df1 = df1[df1.Global_Sales >= 0.2]
df1 = df1.drop(df1.index[[0,1]])
df1
# Out:
#       Rank                            Name Platform    Year         Genre  \
# 2        3                  Mario Kart Wii      Wii  2008.0        Racing
# 3        4               Wii Sports Resort      Wii  2009.0        Sports
# 4        5        Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 5        6                          Tetris       GB  1989.0        Puzzle
# 6        7           New Super Mario Bros.       DS  2006.0      Platform
# ...    ...                             ...      ...     ...           ...
# 7729  7731             Zombie Army Trilogy      PS4  2015.0       Shooter
# 7730  7732                NHL FaceOff 2001      PS2  2001.0        Sports
# 7731  7733  Mana Khemia 2: Fall of Alchemy      PS2  2008.0  Role-Playing
# 7732  7734                The Great Escape      PS2  2003.0        Action
# 7733  7735    Dexter's Lab Chess Challenge      GBA  2002.0          Misc
#
#                         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df1['NA_Ratio']=df1['NA_Sales'] / df1['Global_Sales']
df1['JP_Ratio']=df1['JP_Sales'] / df1['Global_Sales']
df1['EU_Ratio']=df1['EU_Sales'] / df1['Global_Sales']
df1['Other_Ratio']=df1['Other_Sales'] / df1['Global_Sales']
df1
# Out:
#       Rank                            Name Platform    Year         Genre  \
# 2        3                  Mario Kart Wii      Wii  2008.0        Racing
# 3        4               Wii Sports Resort      Wii  2009.0        Sports
# 4        5        Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 5        6                          Tetris       GB  1989.0        Puzzle
# 6        7           New Super Mario Bros.       DS  2006.0      Platform
# ...    ...                             ...      ...     ...           ...
# 7729  7731             Zombie Army Trilogy      PS4  2015.0       Shooter
# 7730  7732                NHL FaceOff 2001      PS2  2001.0        Sports
# 7731  7733  Mana Khemia 2: Fall of Alchemy      PS2  2008.0  Role-Playing
# 7732  7734                The Great Escape      PS2  2003.0        Action
# 7733  7735    Dexter's Lab Chess Challenge      GBA  2002.0          Misc
#
#                         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df_7th_gen = df1.loc[df1['Platform'].isin(['Wii','PS3','X360'])]
df_7th_gen
# Out:
#       Rank                                      Name Platform    Year  \
# 2        3                            Mario Kart Wii      Wii  2008.0
# 3        4                         Wii Sports Resort      Wii  2009.0
# 7        8                                  Wii Play      Wii  2006.0
# 8        9                 New Super Mario Bros. Wii      Wii  2009.0
# 13      14                                   Wii Fit      Wii  2007.0
# ...    ...                                       ...      ...     ...
# 7698  7700                       Shiren the Wanderer      Wii  2008.0
# 7702  7704                                     Conan     X360  2007.0
# 7705  7707                           Warriors Orochi     X360  2007.0
# 7719  7721     Marvel Super Hero Squad: Comic Combat      Wii  2011.0
# 7723  7725  Beyblade: Metal Fusion - Battle Fortress      Wii  2009.0
#
#              Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df.groupby('Genre')['Rank'].nunique()
# Out:
# Genre
# Action          3316
# Adventure       1286
# Fighting         848
# Misc            1739
# Platform         886
# Puzzle           582
# Racing          1249
# Role-Playing    1488
# Shooter         1310
# Simulation       867
# Sports          2346
# Strategy         681
# Name: Rank, dtype: int64

# %%
df_7th_gen.groupby('Genre')['Rank'].nunique()
# Out:
# Genre
# Action          579
# Adventure        61
# Fighting        111
# Misc            281
# Platform         71
# Puzzle           16
# Racing          157
# Role-Playing    143
# Shooter         272
# Simulation       81
# Sports          393
# Strategy         33
# Name: Rank, dtype: int64

# %%
years = df['Year'].unique()
genres = df['Genre'].unique()
sales_columns = [['NA_Sales'],['EU_Sales'],['JP_Sales'],['Other_Sales'],['Global_Sales']]
ratio_columns = [['NA_Ratio'],['EU_Ratio'],['JP_Ratio'],['Other_Ratio']]
sr_columns = sales_columns + ratio_columns
# Out:
# [['NA_Sales'],
#  ['EU_Sales'],
#  ['JP_Sales'],
#  ['Other_Sales'],
#  ['Global_Sales'],
#  ['NA_Ratio'],
#  ['EU_Ratio'],
#  ['JP_Ratio'],
#  ['Other_Ratio']]

# %%
print(df.groupby('Genre').mean()[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']])
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action        0.264726  0.158323  0.048236     0.056508      0.528100
# Adventure     0.082271  0.049868  0.040490     0.013072      0.185879
# Fighting      0.263667  0.119481  0.103007     0.043255      0.529375
# Misc          0.235906  0.124198  0.061967     0.043312      0.465762
# Platform      0.504571  0.227573  0.147596     0.058228      0.938341
# Puzzle        0.212680  0.087251  0.098471     0.021564      0.420876
# Racing        0.287766  0.190865  0.045388     0.061865      0.586101
# Role-Playing  0.219946  0.126384  0.236767     0.040060      0.623233
# Shooter       0.444733  0.239137  0.029221     0.078389      0.791885
# Simulation    0.211430  0.130773  0.073472     0.036355      0.452364
# Sports        0.291283  0.160635  0.057702     0.057532      0.567319
# Strategy      0.100881  0.066579  0.072628     0.016681      0.257151

# %%
stats.f_oneway(df[df['Genre']=='Action']['Global_Sales'],df[df['Genre']=='Adventure']['Global_Sales'],)
# Out:
# F_onewayResult(statistic=104.61683668470822, pvalue=2.6925418307752543e-24)

# %%
stats.ttest_ind(df_7th_gen.NA_Ratio,
                df_7th_gen.JP_Ratio)
# Out:
# Ttest_indResult(statistic=74.68364178233722, pvalue=0.0)

# %%
#fig = experiment_data[experiment_data.test==1][
#    ['treatment_date', 'is_signed_up']].groupby('treatment_date').mean().plot()
#experiment_data[experiment_data.test==0][
#    ['treatment_date', 'is_signed_up']].groupby('treatment_date').mean().plot(ax=fig)
#plt.legend(['test','control'])
#plt.title('Comparing Signup Rates by Treatment Date')
#plt.show()


# Generate a test statistic comparing test and control on treatment date
#print('T-Test Results by Date')

#for date in experiment_data.treatment_date.unique():
#    dated_data = experiment_data[experiment_data.treatment_date == date]
#    print(stats.ttest_ind(dated_data[dated_data.test == 1].is_signed_up,
#                          dated_data[dated_data.test == 0].is_signed_up))


for date in df.Year.unique():
    year = df[df.Year == date]
    print(stats.ttest_ind(year.JP_Sales,
                          year.NA_Sales))
# Out:
# Ttest_indResult(statistic=-3.9086870466917314, pvalue=9.586710983005019e-05)
# Ttest_indResult(statistic=-0.6499826250528288, pvalue=0.52140553509578)
# Ttest_indResult(statistic=-11.490969034015643, pvalue=6.591889966171544e-30)
# Ttest_indResult(statistic=-9.051132710601147, pvalue=2.5518322151865936e-19)
# Ttest_indResult(statistic=-1.4715841879125733, pvalue=0.14173348954370069)
# Ttest_indResult(statistic=-1.077134598551213, pvalue=0.289473698391)
# Ttest_indResult(statistic=-0.713425518581188, pvalue=0.4819377097837497)
# Ttest_indResult(statistic=-8.977653724778051, pvalue=6.541694737311027e-19)
# Ttest_indResult(statistic=-4.266058182865309, pvalue=2.2742949769022944e-05)
# Ttest_indResult(statistic=-11.384770939139187, pvalue=2.764991616933733e-29)
# Ttest_indResult(statistic=-8.917547137070086, pvalue=8.959161656373776e-19)
# Ttest_indResult(statistic=-5.55776675512652, pvalue=3.434207798947289e-08)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-165d1922d6ef> in <module>
# ----> 1 df.year
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'year'
